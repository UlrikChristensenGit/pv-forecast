# %%
from web.app.integrations.dataset import Dataset
from etl.etl.integrations.log import Log
import dotenv

# %%
dataset = Dataset("latest_nwp")

# %%
ds = dataset.read()

# %%
ds0 = ds.sel(time_utc="2024-11-27 06:00:00", x=1, y=1)

# %%
ds0["altitude_m"].values.min()
# Out:
# np.float64(0.0)

# %%
ds0

# %%
ds0

# %%
ds0.compute()

# %%
ds.unify_chunks()

# %%
ds.sel(time_utc=slice('2024-11-26', '2024-11-27')).isel(x=0, y=0).compute()
